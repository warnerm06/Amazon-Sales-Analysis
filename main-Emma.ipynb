# %%
# %matplotlib notebook

# %%
#dependencies
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
pd.set_option('display.max_columns', 50) #expand all dfs otherwise df with many columsn will be truncated

# %%
#import csv data files
# File to Load 
ad_data_to_load = "csv_data/Ad3.csv" #ad data file (only working with 1 of the 3)
cost_of_goods_to_load = "csv_data/cost_of_goods.csv" #cost of goods file
transactions_to_load="csv_data/transactions_main.csv" #transactions file

# Read the csvs
ad_data_raw =pd.read_csv(ad_data_to_load, index_col=False)
cost_of_goods_raw =pd.read_csv(cost_of_goods_to_load)
transactions_raw =pd.read_csv(transactions_to_load)

#create dfs
ad_df_raw = pd.DataFrame(ad_data_raw)
cog_df_raw = pd.DataFrame(cost_of_goods_raw)
trans_df_raw = pd.DataFrame(transactions_raw)

#merge trans df and cost of goods df together on 'sku'
combo_df =pd.merge(trans_df_raw, cog_df_raw, how='inner', on='sku', left_on=None, right_on=None,
         left_index=False, right_index=False, sort=True,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
combo_df.loc[:, 'date/time'].replace(regex=True,inplace=True,to_replace="PST", value="") #remove 'PST' from date/time; if PST or PDT remain an error will occur when converting 
combo_df.loc[:, 'date/time'].replace(regex=True,inplace=True,to_replace="PDT", value="") #remove 'PDT' from date/time; if PST or PDT remain an error will occur when converting
combo_df['date/time']=pd.to_datetime(combo_df['date/time']) #converts string date/time to datetime
combo_df.infer_objects(); #changes column types. Most are strings or objects and this converts them to floats. This may not be needed. Need to double check. But it works so keep it for now.

# %%
def trans_cols(x): #creates new cols and their calculations
    x['transaction revenue']= x['total']-x['est_cost_unit']#revenue generate from transaction (revenue - cost of goods)
    x['sale price']= x['product sales']/x['quantity']#generates price of item at sale
    #x['Day of Week']=""  #Mon, Tues, Weds etc...
    x['Cost of Goods']=x['quantity']*x['est_cost_unit'] #total cost of goods for transaction; used to tally reorder amounts
    x['Whole Date'] =pd.to_datetime(combo_df['date/time']).apply(lambda y: y.date()) #converts timestamp to date
    
trans_cols(combo_df) #apply the trans_cols function to create new columns
short_trans_df=combo_df.drop(['settlement id','order id','marketplace','fulfillment'],axis=1) #drop unimportant columns and create a smaller df
short_trans_df.sort_values('date/time').reset_index().head(40) #sort df and reset index to match
# Out:
#     index           date/time   type           sku  \
# 0     345 2015-04-15 18:48:48  Order  48-JT2Z-XFJ6
# 1    8051 2015-04-17 12:47:22  Order  B5-0ROP-233D
# 2   15171 2015-04-18 22:09:29  Order  MU-6BI2-VLJV
# 3    8060 2015-04-18 23:12:22  Order  BF-MG8U-OWWI
# 4     346 2015-04-20 00:18:22  Order  48-JT2Z-XFJ6
# 5     347 2015-04-20 02:42:30  Order  48-JT2Z-XFJ6
# 6     348 2015-04-20 16:28:56  Order  48-JT2Z-XFJ6
# 7     349 2015-04-21 00:35:10  Order  48-JT2Z-XFJ6
# 8     350 2015-04-21 16:13:54  Order  48-JT2Z-XFJ6
# 9     351 2015-04-22 17:25:38  Order  48-JT2Z-XFJ6
# 10    352 2015-04-22 19:25:07  Order  48-JT2Z-XFJ6
# 11    353 2015-04-23 02:38:22  Order  48-JT2Z-XFJ6
# 12   8061 2015-04-24 03:16:38  Order  BF-MG8U-OWWI
     0.0    0.0  14.32  NaN   NaN  Chocolate Eggs
# 35                     0.0    0.0   5.82  NaN   NaN  Chocolate Eggs
# 36                     0.0    0.0   5.82  NaN   NaN  Chocolate Eggs
# 37                     0.0    0.0   5.82  NaN   NaN  Chocolate Eggs
# 38                     0.0    0.0  14.32  NaN   NaN  Chocolate Eggs
# 39                     0.0    0.0   6.82  NaN   NaN  Chocolate Eggs
#
#                         child  est_cost_unit  pick_n_pack_fee  \
# 0       Frozen Chocolate Eggs           2.31              NaN
# 1     Princess Chocolate Eggs           2.31              NaN
# 2         Cars Chocolate Eggs           2.31              NaN
# 3   Spider Man Chocolate Eggs           2.31              NaN
# 4       Frozen Chocolate Eggs           2.31              NaN
# 5       Frozen Chocolate Eggs           2.31              NaN
# 6       Frozen Chocolate Eggs           2.31              NaN
# 7       Frozen Chocolate Eggs           2.31              NaN
# 8       Frozen Chocolate Eggs           2.31              NaN
# 9       Frozen Chocolate Eggs           2.31              NaN
# 10      Frozen Chocolate Eggs           2.31              NaN
# 11      Frozen Chocolate Eggs           2.31              NaN
# 12  Spider Man Chocolate Eggs           2.31              NaN
# 13      Frozen Chocolate Eggs           2.31              NaN
# 14  Spider Man Chocolate Eggs           2.31              NaN
# 15  Spider Man Chocolate Eggs           2.31              NaN
# 16  Spider Man Chocolate Eggs           2.31              NaN
# 17  Spider Man Chocolate Eggs           2.31              NaN
# 18      Frozen Chocolate Eggs           2.31              NaN
# 19  Spider Man Chocolate Eggs           2.31              NaN
# 20      Frozen Chocolate Eggs           2.31              NaN
# 21  Spider Man Chocolate Eggs           2.31              NaN
# 22        Cars Chocolate Eggs           2.31              NaN
# 23    Princess Chocolate Eggs           2.31              NaN
# 24    Princess Chocolate Eggs           2.31              NaN
# 25    Princess Chocolate Eggs           2.31              NaN
# 26      Frozen Chocolate Eggs           2.31              NaN
# 27      Frozen Chocolate Eggs           2.31              NaN
# 28    Princess Chocolate Eggs           2.31              NaN
# 29      Frozen Chocolate Eggs           2.31              NaN
# 30        Cars Chocolate Eggs           2.31              NaN
# 31      Frozen Chocolate Eggs           2.31              NaN
# 32    Princess Chocolate Eggs           2.31              NaN
# 33      Frozen Chocolate Eggs           2.31              NaN
# 34  Spider Man Chocolate Eggs           2.31              NaN
# 35      Frozen Chocolate Eggs           2.31              NaN
# 36      Frozen Chocolate Eggs           2.31              NaN
# 37      Frozen Chocolate Eggs           2.31              NaN
# 38  Spider Man Chocolate Eggs           2.31              NaN
# 39  Spider Man Chocolate Eggs           2.31              NaN
#
#     transaction revenue  sale price  Cost of Goods  Whole Date
# 0                 13.71       21.99           2.31  2015-04-15
# 1                 13.71       21.99           2.31  2015-04-17
# 2                 13.71       21.99           2.31  2015-04-18
# 3                 13.71       21.99           2.31  2015-04-18
# 4                 13.71       21.99           2.31  2015-04-20
# 5                 13.71       21.99           2.31  2015-04-20
# 6                 13.71       21.99           2.31  2015-04-20
# 7                 13.71       21.99           2.31  2015-04-21
# 8                 13.71       21.99           2.31  2015-04-21
# 9                 12.01       19.99           2.31  2015-04-22
iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 10     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 11     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 12     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 13     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 14     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 15     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 16     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 17     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 18     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 19     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 20     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 21     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 22     Iconic Home Bamboo 3 Tier Salt Box Container W...       2.0
# 23     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 24     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 25     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 26     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 27     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 28     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# 29     Iconic Home Bamboo 3 Tier Salt Box Container W...       1.0
# ...                                                  ...       ...
# 24564  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24565  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24566  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24567  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24568  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24569  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24570  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24571  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24572      FBA Inventory Reimbursement - Customer Return       1.0
# 24573  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24574  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24575  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24576  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24577  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24578  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24579  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24580  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24581  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24582  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24583  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24584  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24585  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24586  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24587  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24588  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24589  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24590  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24591  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24592  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
# 24593  The Ultimate Paracord Survival Kit Bracelet (L...       1.0
#
#             order city order state order postal  product sales  \
# 0             Lawrence          KS        66049           0.00
# 1             Lawrence          KS        66049           0.00
# 2            St. Louis          MO        63139           0.00
# 3            St. Louis          MO        63139           0.00
# 4             Wildwood          MO        63040           0.00
# 5             Wildwood          MO        63040           0.00
# 6               Aurora          IL   60506-1573          29.85
# 7               Aurora          IL   60506-1573          29.85
# 8           HUNTSVILLE          AL        35801          19.90
# 9        Beverly Hills          CA        90212           9.95
# 10       Beverly Hills          CA        90212           9.95
# 11         Marlborough          Ma         1752           9.95
# 12         Marlborough          Ma         1752           9.95
# 13             HOUSTON          TX   77008-4525           9.95
# 14              DACULA          GA   30019-1564           9.95
# 15       SAN FRANCISCO          CA   94103-3766           9.95
# 16      Virginia Beach          VA   23454-2202           9.95
# 17          Las Cruces          NM        88007           9.95
# 18           FAIRBANKS      ALASKA   99709-3324           9.95
# 19          WASHINGTON          DC   20009-6849           9.95
# 20              NEENAH          WI   54956-1235           9.95
# 21          BURLINGTON          NJ   08016-4605           9.95
# 22      WEST GREENWICH          RI   02817-1667          19.90
# 23        JACKSONVILLE          FL   32256-0844           9.95
# 24             Chicago          IL        60618           9.95
# 25      Ft. Lauderdale     Florida        33309           9.95
# 26              DALLAS          TX   75287-2130           9.95
# 27          FORT WORTH          TX   76244-5622           9.95
# 28            BROOKLYN          NY   11211-5698           9.95
# 29         JOHNS CREEK          GA   30097-2308           9.95
# ...                ...         ...          ...            ...
# 24564       SCOTTSDALE          AZ   85250-6701          17.95
# 24565         RAYVILLE          LA   71269-7644          17.95
# 24566      ALBUQUERQUE          NM   87123-1222          17.95
# 24567      LOS ANGELES          CA   90049-6397          17.95
# 24568          CARDIFF          CA   92007-1821          17.95
# 24569        PARACHUTE          CO   81635-9517          17.95
# 24570    ELLSWORTH AFB          SD   57706-6406          17.95
# 24571            TULSA          OK   74114-6109          17.95
# 24572              NaN         NaN          NaN           0.00
# 24573        Wauwatosa          WI        53213          17.95
# 24574           AUSTIN          TX   78757-4443          17.95
# 24575         LA PLATA          MD   20646-3286          17.95
# 24576         NEW YORK    NEW YORK   10065-7742          17.95
# 24577          Waconia          MN        55387          17.95
# 24578          KOUNTZE          TX   77625-4005          17.95
# 24579     PORT ANGELES          WA   98363-9112          17.95
-4.18                     0.0   0.00   4.28  B01N5TVYVD
# 14        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 15        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 16        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 17        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 18        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 19        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 20        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 21        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 22        -8.36                     0.0   0.00   8.56  B01N5TVYVD
# 23        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 24        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 25        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 26        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 27        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 28        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# 29        -4.18                     0.0   0.00   4.28  B01N5TVYVD
# ...         ...                     ...    ...    ...         ...
# 24564     -2.88                     0.0   0.00  12.38  B00WW1H5FS
# 24565     -2.88                     0.0   0.00  12.38  B00WW1H5FS
# 24566     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24567     -2.99                     0.0   0.00  14.96  B00WW1H5FS
# 24568     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24569     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24570     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24571     -8.17                     0.0   0.00  12.27  B00WW1H5FS
# 24572      0.00                     0.0  12.27  12.27  B00WW1H5FS
# 24573     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24574     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24575     -8.17                     0.0   0.00  12.27  B00WW1H5FS
# 24576     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24577     -2.99                     0.0   0.00  12.27  B00WW1H5FS
# 24578     -4.28                     0.0   0.00  12.27  B00WW1H5FS
# 24579     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24580     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24581     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24582     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24583     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24584     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24585     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24586     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24587      0.00                     0.0   0.00 -15.80  B00WW1H5FS
# 24588     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24589     -6.68                     0.0   0.00  12.07  B00WW1H5FS
# 24590     -8.37                     0.0   0.00  12.07  B00WW1H5FS
# 24591     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24592     -3.19                     0.0   0.00  12.07  B00WW1H5FS
# 24593     -3.19                     0.0   0.00  12.07  B00WW1H5FS
#
#                    group           parent            child  est_cost_unit  \
# 0      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 1      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 2      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 3      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 4      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 5      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 6      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 7      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 8      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 9      Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 10     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 11     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 12     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 13     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 14     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 15     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 16     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 17     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 18     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 19     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 20     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 21     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 22     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 23     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 24     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 25     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 26     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 27     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 28     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# 29     Bamboo Salt Boxes  Bamboo Salt Box  Bamboo Salt Box           0.66
# ...                  ...              ...              ...            ...
# 24564   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24565   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24566   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24567   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24568   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24569   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24570   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24571   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24572   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24573   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24574   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24575   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24576   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24577   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24578   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24579   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24580   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24581   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24582   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24583   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24584   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24585   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24586   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24587   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24588   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24589   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24590   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24591   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24592   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
# 24593   Toggle Bracelets  Toggle Bracelet      Black Large           2.31
#
#        pick_n_pack_fee  transaction revenue  sale price  Cost of Goods  \
# 0                 4.18                -6.16        0.00           0.66
# 1                 4.18                -1.41        0.00           0.66
# 2                 4.18                -9.16        0.00           0.66
# 3                 4.18                -1.41        0.00           0.66
# 4                 4.18                -9.16        0.00           0.66
# 5                 4.18                -1.41        0.00           0.66
# 6                 4.18                -1.23        9.95           1.98
# 7                 4.18                16.65        9.95           1.98
# 8                 4.18                 7.90        9.95           1.32
# 9                 4.18                 2.13        9.95           0.66
# 10                4.18                 5.11        9.95           0.66
# 11                4.18                 2.13        9.95           0.66
# 12                4.18                 5.11        9.95           0.66
# 13                4.18                 3.62        9.95           0.66
# 14                4.18                 3.62        9.95           0.66
# 15                4.18                 3.62        9.95           0.66
# 16                4.18                 3.62        9.95           0.66
# 17                4.18                 3.62        9.95           0.66
# 18                4.18                 3.62        9.95           0.66
# 19                4.18                 3.62        9.95           0.66
# 20                4.18                 3.62        9.95           0.66
# 21                4.18                 3.62        9.95           0.66
# 22                4.18                 7.90        9.95           1.32
# 23                4.18                 3.62        9.95           0.66
# 24                4.18                 3.62        9.95           0.66
# 25                4.18                 3.62        9.95           0.66
# 26                4.18                 3.62        9.95           0.66
# 27                4.18                 3.62        9.95           0.66
# 28                4.18                 3.62        9.95           0.66
# 29                4.18                 3.62        9.95           0.66
# ...                ...                  ...         ...            ...
# 24564             2.99                10.07       17.95           2.31
# 24565             2.99                10.07       17.95           2.31
# 24566             2.99                 9.96       17.95           2.31
# 24567             2.99                12.65       17.95           2.31
# 24568             2.99                 9.96       17.95           2.31
# 24569             2.99                 9.96       17.95           2.31
# 24570             2.99                 9.96       17.95           2.31
# 24571             2.99                 9.96       17.95           2.31
# 24572             2.99                 9.96        0.00           2.31
# 24573             2.99                 9.96       17.95           2.31
# 24574             2.99                 9.96       17.95           2.31
# 24575             2.99                 9.96       17.95           2.31
# 24576             2.99                 9.96       17.95           2.31
# 24577             2.99                 9.96       17.95           2.31
# 24578             2.99                 9.96       17.95           2.31
# 24579             2.99                 9.76       17.95           2.31
# 24580             2.99                 9.76       17.95           2.31
# 24581             2.99                 9.76       17.95           2.31
# 24582             2.99                 9.76       17.95           2.31
# 24583             2.99                 9.76       17.95           2.31
# 24584             2.99                 9.76       17.95           2.31
# 24585             2.99                 9.76       17.95           2.31
# 24586             2.99                 9.76       17.95           2.31
# 24587             2.99               -18.11      -17.95           2.31
# 24588             2.99                 9.76       17.95           2.31
# 24589             2.99                 9.76       17.95           2.31
# 24590             2.99                 9.76       17.95           2.31
# 24591             2.99                 9.76       17.95           2.31
# 24592             2.99                 9.76       17.95           2.31
# 24593             2.99                 9.76       17.95           2.31
#
#        Whole Date  month
# 0      2017-02-07      2
# 1      2017-02-07      2
# 2      2017-04-11      4
# 3      2017-04-11      4
# 4      2017-05-11      5
# 5      2017-05-11      5
# 6      2017-06-07      6
# 7      2017-06-07      6
# 8      2017-06-20      6
# 9      2017-06-20      6
# 10     2017-06-20      6
# 11     2017-06-21      6
# 12     2017-06-21      6
# 13     2017-06-22      6
# 14     2017-06-26      6
# 15     2017-06-27      6
# 16     2017-06-28      6
# 17     2017-07-05      7
# 18     2017-07-05      7
# 19     2017-07-05      7
# 20     2017-07-06      7
# 21     2017-07-08      7
# 22     2017-07-10      7
# 23     2017-07-12      7
# 24     2017-07-13      7
# 25     2017-07-14      7
# 26     2017-07-14      7
# 27     2017-07-16      7
# 28     2017-07-16      7
# 29     2017-07-16      7
# ...           ...    ...
# 24564  2017-12-29     12
# 24565  2017-12-29     12
# 24566  2018-01-06      1
# 24567  2018-01-12      1
# 24568  2018-01-16      1
# 24569  2018-01-18      1
# 24570  2018-01-18      1
# 24571  2018-01-23      1
# 24572  2018-01-25      1
# 24573  2018-01-26      1
# 24574  2018-02-07      2
# 24575  2018-02-09      2
# 24576  2018-02-14      2
# 24577  2018-02-17      2
# 24578  2018-02-18      2
# 24579  2018-02-24      2
# 24580  2018-03-03      3
# 24581  2018-03-07      3
# 24582  2018-03-13      3
# 24583  2018-03-20      3
# 24584  2018-04-05      4
# 24585  2018-04-10      4
# 24586  2018-04-11      4
# 24587  2018-05-04      5
# 24588  2018-05-05      5
# 24589  2018-05-06      5
# 24590  2018-05-30      5
# 24591  2018-06-13      6
# 24592  2018-07-17      7
# 24593  2018-07-24      7
#
# [24594 rows x 30 columns]

# %%
#only keep the columns we need.
shorter_trans = short_trans_df.loc[:,['sku','description','type','quantity','month']]

shorter_trans.head(10)
# Out:
#             sku                                        description   type  \
# 0  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 1  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 2  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 3  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 4  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 5  1I-A550-7LTL                     Bamboo Salt Box by Iconic Home  Order
# 6  1I-A550-7LTL  Iconic Home Bamboo 3 Tier Salt Box Container W...  Order
# 7  1I-A550-7LTL  Iconic Home Bamboo 3 Tier Salt Box Container W...  Order
# 8  1I-A550-7LTL  Iconic Home Bamboo 3 Tier Salt Box Container W...  Order
# 9  1I-A550-7LTL  Iconic Home Bamboo 3 Tier Salt Box Container W...  Order
#
#    quantity  month
# 0       1.0      2
# 1       1.0      2
# 2       1.0      4
# 3       1.0      4
# 4       1.0      5
# 5       1.0      5
# 6       3.0      6
# 7       3.0      6
# 8       2.0      6
# 9       1.0      6

# %%
#find each itme's sale quantities
shortest = shorter_trans.groupby('sku').count()
shortest.head()
# Out:
#               description  type  quantity  month
# sku
# 1I-A550-7LTL          307   307       307    307
# 3C-6EO3-6BZM            9     9         9      9
# 3H-PI6M-79YU           21    21        21     21
# 3N-EYM5-NTCE            8     8         8      8
# 48-JT2Z-XFJ6           35    35        35     35

# %%
#use item which sales quantity > 2000
filter2 = shorter_trans['sku'].isin(['HC-BC84-DIQ5','UK-AVWR-4MNQ','W4-GNMR-2X7O'])
combin1 = shorter_trans[filter2]
combin1.head()
# Out:
#                sku                                        description   type  \
# 9820  HC-BC84-DIQ5  Silicone Pet Food Mat by Tip-Top Petware, Mult...  Order
# 9821  HC-BC84-DIQ5  Silicone Pet Food Mat by Tip-Top Petware, Mult...  Order
# 9822  HC-BC84-DIQ5  Silicone Pet Food Mat by Tip-Top Petware, Mult...  Order
# 9823  HC-BC84-DIQ5  Silicone Pet Food Mat by Tip-Top Petware, Mult...  Order
# 9824  HC-BC84-DIQ5  Silicone Pet Food Mat by Tip-Top Petware, Mult...  Order
#
#       quantity  month
# 9820       1.0      5
# 9821       1.0      5
# 9822       1.0      5
# 9823       1.0      5
# 9824       1.0      6

# %%
#use month to group non-summer items
other_total = combin1.groupby(['month']).sum()
other_total
# Out:
#        quantity
# month
# 1        1210.0
# 2         988.0
# 3         907.0
# 4        1072.0
# 5        1069.0
# 6         956.0
# 7         950.0
# 8         805.0
# 9         769.0
# 10       1051.0
# 11        881.0
# 12       1564.0

# %%
# non-summer item total sales plot
other_total.plot();

plt.xlabel("Month")
plt.ylabel("sales quantity")
plt.savefig("Images/other_item_total_sale.png")

# %%
otherSep=combin1.groupby(['month','sku']).sum()
otherSep=otherSep.reset_index()
otherSep.head()
# Out:
#    month           sku  quantity
# 0      1  HC-BC84-DIQ5     595.0
# 1      1  UK-AVWR-4MNQ     123.0
# 2      1  W4-GNMR-2X7O     492.0
# 3      2  HC-BC84-DIQ5     360.0
# 4      2  UK-AVWR-4MNQ     378.0

# %%
otherreform = otherSep.pivot(index ='month',columns ='sku', values ='quantity')
otherreform = otherreform.fillna(0)
otherreform
# Out:
# sku    HC-BC84-DIQ5  UK-AVWR-4MNQ  W4-GNMR-2X7O
# month
# 1             595.0         123.0         492.0
# 2             360.0         378.0         250.0
# 3             375.0         316.0         216.0
# 4             445.0         282.0         345.0
# 5             295.0         308.0         466.0
# 6             250.0         341.0         365.0
# 7             356.0         328.0         266.0
# 8             357.0         254.0         194.0
# 9             436.0          37.0         296.0
# 10            366.0         200.0         485.0
# 11            123.0         289.0         469.0
# 12            352.0         684.0         528.0

# %%
# 
otherSkuName=otherSep['sku'].unique()


plt.figure(figsize = (15,10))
plt.title('non-Sumer items Sales by month')
plt.xlabel('Month') 
plt.ylabel('sales quantity') 
plt.xticks(np.arange(0, 12 , 1)) 
plt.grid(True)
xvals = otherreform.index



for i in otherSkuName:
    plt.plot(xvals, 
            otherreform[i], 
            linestyle = '--',
            marker =  "^") 
 
legend =plt.legend(loc="best")   

plt.show()
plt.savefig("Images/other_item_separate_sale.png")

# %%
#combin three antguard items together 
filter1=shorter_trans['sku'].isin(['5B-FPT4-XKWM','Ant Guard Qty 2','Ant Guard Qty 3','AX-HJ6W-YXN8'])
combin=shorter_trans[filter1]
combin.head()
# Out:
#               sku                                        description   type  \
# 380  5B-FPT4-XKWM  Copper Hummingbird Feeder Ant Guard by Tip-Top...  Order
# 381  5B-FPT4-XKWM  Copper Hummingbird Feeder Ant Guard by Tip-Top...  Order
# 382  5B-FPT4-XKWM  Copper Hummingbird Feeder Ant Guard by Tip-Top...  Order
# 383  5B-FPT4-XKWM  Copper Hummingbird Feeder Ant Guard by Tip-Top...  Order
# 384  5B-FPT4-XKWM  Copper Hummingbird Feeder Ant Guard by Tip-Top...  Order
#
#      quantity  month
# 380       1.0      6
# 381       1.0      6
# 382       1.0      6
# 383       1.0      6
# 384       1.0      6

# %%
# total sales quantity for each month in antguard items
Garden_total=combin.groupby(['month']).sum()
Garden_total
# Out:
#        quantity
# month
# 1         108.0
# 2         209.0
# 3         490.0
# 4         974.0
# 5        1304.0
# 6         886.0
# 7        1308.0
# 8         778.0
# 9         461.0
# 10        268.0
# 11        135.0
# 12        178.0

# %%
#the summer items total sales for each month plot
Garden_total.plot();

plt.xlabel("Month")
plt.ylabel("sales quantity")
plt.savefig("Images/summer_item_total_sale.png")

# %%
#separate into 3 items to see if there's any different in sales
GardenSep=combin.groupby(['month','sku']).sum()
GardenSep=GardenSep.reset_index()
GardenSep.head()
# Out:
#    month              sku  quantity
# 0      1     5B-FPT4-XKWM       1.0
# 1      1     AX-HJ6W-YXN8      80.0
# 2      1  Ant Guard Qty 2       8.0
# 3      1  Ant Guard Qty 3      19.0
# 4      2     5B-FPT4-XKWM       4.0

# %%
reform=GardenSep.pivot(index='month',columns='sku', values='quantity')
reform=reform.fillna(0)
reform.head()
# Out:
# sku    5B-FPT4-XKWM  AX-HJ6W-YXN8  Ant Guard Qty 2  Ant Guard Qty 3
# month
# 1               1.0          80.0              8.0             19.0
# 2               4.0         140.0             31.0             34.0
# 3               3.0         312.0             46.0            129.0
# 4              10.0         654.0             85.0            225.0
# 5              16.0         968.0             79.0            241.0

# %%
# 3 antguard items plot
SkuName=GardenSep['sku'].unique()


plt.figure(figsize = (15,10))
plt.title('Sales by month')
plt.xlabel('Month') 
plt.ylabel('sales quantity') 
plt.xticks(np.arange(0, 12 , 1)) 
plt.grid(True)
xvals = reform.index



for i in SkuName:
    plt.plot(xvals, 
            reform[i], 
            linestyle = '-',
            marker =  "*") 
 
legend =plt.legend(loc="best")   

plt.show()
plt.savefig("Images/summer_item_separate_sale.png")

# %%
ad_data_clean=ad_data_raw
ad_data_clean['Date'] =pd.to_datetime(ad_data_clean['Date']).apply(lambda y: y.date())#converts string date to date

def ad_cols(x): #creates new cols and their calculations
    x['Whole Date'] =pd.to_datetime(ad_data_clean['Date']).apply(lambda y: y.date()) #converts timestamp to date
    
ad_cols(ad_data_clean) #apply the trans_cols function to create new columns
short_ad_df=ad_data_clean.drop(['Currency'],axis=1) #drop unimportant columns and create a smaller df
short_ad_df['Spend']=short_ad_df['Spend'].replace('[\$,]', '', regex=True).astype(float) #removes $ and converts to float
short_ad_df

# %%
itemName=short_ad_df.groupby(["Advertised ASIN"])
itemName

# %%
#profit graph
def profit_graph():
    
    def trans_rev(x): #create a df with sum transactions grouped by date
        cols={'Transaction Revenue':x['transaction revenue'].sum()}
        return pd.Series(cols)
    rev_df=combo_df.groupby('Whole Date').apply(trans_rev)
    rev_df.reset_index;()#reset index so "Whole Date" can be used
     
    def ad_spend_daily(x): #create a df with sum transactions grouped by date
        cols={'Ad Spend':x['Spend'].sum()}
        return pd.Series(cols)
    daily_ad_spend_df=short_ad_df.groupby(['Date']).apply(ad_spend_daily)
    
    prof_df =pd.merge(daily_ad_spend_df, rev_df, how='outer', left_on="Date", right_on="Whole Date",
             left_index=False, right_index=True, sort=True,
             suffixes=('_x', '_y'), copy=True, indicator=False,
             validate=None)
    #prof_df.head()
    prof_df['Profit']=prof_df['Transaction Revenue']-prof_df['Ad Spend']
    prof_df['Profit'].fillna(prof_df['Transaction Revenue'],inplace=True)
    x=prof_df.index
    y=prof_df['Profit'] 
    
    fig = plt.figure(figsize=(50,10))#creates figure
    ax= fig.add_subplot(1,1,1)
    ax.set_ylim([0,600])
    ax.plot(x, y)
    ax.set_title('Daily Profit')
    ax.set_xlabel('Date')
    ax.set_ylabel('USD $')
    ax.legend(loc='best')

    
    myFmt = mdates.DateFormatter('%B%y')
    ax.xaxis.set_major_formatter(myFmt)
    
profit_graph()
